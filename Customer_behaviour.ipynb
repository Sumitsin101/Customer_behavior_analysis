# %%
# importing necessary libraries

import pandas as pd
import numpy as np

# %%
# loading dataset and assgning it to a variable called df

df=pd.read_csv('customer_shopping_behavior.csv')
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
# To check the count   of rows and columns

df.shape
# Out:
# (3900, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 548.6+ KB

# %%
# checking for null values

df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
# Change the column names to snake_case so they’re easier to read and document

df.columns=df.columns.str.lower().str.replace(' ','_')
df=df.rename(columns={'purchase_amount_(usd)':'purchase_amount','promo_code_used':'promo_code','frequency_of_purchases':'buy_freq'})

# %%
df['category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
# filling missing values with median but grouping by category for more accurate results

df['review_rating']=df.groupby(['category'])['review_rating'].transform(lambda a:a.fillna(a.median()))

# %%
df.isnull().sum()
# Out:
# customer_id            0
# age                    0
# gender                 0
# item_purchased         0
# category               0
# purchase_amount        0
# location               0
# size                   0
# color                  0
# season                 0
# review_rating          0
# subscription_status    0
# shipping_type          0
# discount_applied       0
# promo_code             0
# previous_purchases     0
# payment_method         0
# buy_freq               0
# dtype: int64

# %%
# Created a new column called age_group to categorise different age of shoppers

df['age_group']=pd.qcut(df['age'],q=4,labels=['Young','Adult','Middle Aged','Senior'])

# %%
df[['age','age_group']]
# Out:
#       age    age_group
# 0      55  Middle Aged
# 1      19        Young
# 2      50  Middle Aged
# 3      21        Young
# 4      45  Middle Aged
# ...   ...          ...
# 3895   40        Adult
# 3896   52  Middle Aged
# 3897   46  Middle Aged
# 3898   44        Adult
# 3899   52  Middle Aged
#
# [3900 rows x 2 columns]

# %%
df['buy_freq'].unique()
# Out:
# array(['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
#        'Monthly', 'Every 3 Months'], dtype=object)

# %%
# Converted column buy_freq/ frequency of purchase into numeric for better analysis

df['buy_freq']=df['buy_freq'].map({'Fortnightly': 14,'Weekly': 7,'Monthly': 30,'Quarterly': 90,'Bi-Weekly': 14,'Annually': 365,'Every 3 Months': 90})

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied promo_code  previous_purchases  \
# 0        Express              Yes        Yes                  14
# 1        Express              Yes        Yes                   2
# 2  Free Shipping              Yes        Yes                  23
# 3   Next Day Air              Yes        Yes                  49
# 4  Free Shipping              Yes        Yes                  31
#
#   payment_method  buy_freq    age_group
# 0          Venmo        14  Middle Aged
# 1           Cash        14        Young
# 2    Credit Card         7  Middle Aged
# 3         PayPal         7        Young
# 4         PayPal       365  Middle Aged

# %%
#checking if discount_applied and promo_code have simiar values 

(df['discount_applied'] == df['promo_code']).all()
# Out:
# True

# %%
#Deleting column discount_applied because it has similar values to promo_code 

df=df.drop(columns='discount_applied')

# %%
df.head(10)
# Out:
#    customer_id  age gender item_purchased     category  purchase_amount  \
# 0            1   55   Male         Blouse     Clothing               53
# 1            2   19   Male        Sweater     Clothing               64
# 2            3   50   Male          Jeans     Clothing               73
# 3            4   21   Male        Sandals     Footwear               90
# 4            5   45   Male         Blouse     Clothing               49
# 5            6   46   Male       Sneakers     Footwear               20
# 6            7   63   Male          Shirt     Clothing               85
# 7            8   27   Male         Shorts     Clothing               34
# 8            9   26   Male           Coat    Outerwear               97
# 9           10   57   Male        Handbag  Accessories               31
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
# 5        Wyoming    M      White  Summer            2.9                 Yes
# 6        Montana    M       Gray    Fall            3.2                 Yes
# 7      Louisiana    L   Charcoal  Winter            3.2                 Yes
# 8  West Virginia    L     Silver  Summer            2.6                 Yes
# 9       Missouri    M       Pink  Spring            4.8                 Yes
#
#     shipping_type promo_code  previous_purchases payment_method  buy_freq  \
# 0         Express        Yes                  14          Venmo        14
# 1         Express        Yes                   2           Cash        14
# 2   Free Shipping        Yes                  23    Credit Card         7
# 3    Next Day Air        Yes                  49         PayPal         7
# 4   Free Shipping        Yes                  31         PayPal       365
# 5        Standard        Yes                  14          Venmo         7
# 6   Free Shipping        Yes                  49           Cash        90
# 7   Free Shipping        Yes                  19    Credit Card         7
# 8         Express        Yes                   8          Venmo       365
# 9  2-Day Shipping        Yes                   4           Cash        90
#
#      age_group
# 0  Middle Aged
# 1        Young
# 2  Middle Aged
# 3        Young
# 4  Middle Aged
# 5  Middle Aged
# 6       Senior
# 7        Young
# 8        Young
# 9  Middle Aged

# %% [markdown]
# # Connecting to Mysql for deeper analysis

# %%
pip install pymysql sqlalchemy
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: sqlalchemy in c:\users\hp\anaconda3\lib\site-packages (2.0.34)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\hp\anaconda3\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\hp\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# MySQL connection
username = "root"
password = "admin"
host = "localhost"
port = "3306"
database = "customer_behavior"

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# Write DataFrame to MySQL
table_name = "customer"   
df.to_sql(table_name, engine, if_exists="replace", index=False)

# Read back sample
pd.read_sql("SELECT * FROM customer LIMIT 5;", engine)
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type promo_code  previous_purchases payment_method  buy_freq  \
# 0        Express        Yes                  14          Venmo        14
# 1        Express        Yes                   2           Cash        14
# 2  Free Shipping        Yes                  23    Credit Card         7
# 3   Next Day Air        Yes                  49         PayPal         7
# 4  Free Shipping        Yes                  31         PayPal       365
#
#      age_group
# 0  Middle Aged
# 1        Young
# 2  Middle Aged
# 3        Young
# 4  Middle Aged
